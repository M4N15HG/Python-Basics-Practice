# %% [markdown]
# # Pandas
# * Built on numpy
# * Importing and analyzing data
# * Pandas has Dataframe data structure which is similar to excel sheet.
# * 3 Data Structures : Series(1-D), DataFrames(2-D), Panel(3-D).
# * Normally From array we create Series, from Series we create DataFrame, from DataFrame we create Panel

# %%
# !pip install pandas

# %%
import pandas as pd # Importing pandas

# %%
pd.__version__ # Checking Version
# Out:
# '1.2.4'

# %% [markdown]
# * Series is 1-D
# * DataFrame is 2-D
# * Array is nD
#
# Array does not have coloumn names/ Coloumn indexs
# Series and DataFrames have coloumn names

# %% [markdown]
# # Series
# * Series is a 1- dimensional array.
# * Length is immutable but Data is mutable
# * Stores same type of data(Homogeneous)
# * One Dimensional array with a coloumn name.
#
# pandas.Series(data, index , dtype ,copy )
#
# Parameter description :
# - Data -- it takes various forms like list , ndarray , constant.
# - index--its value is unique and same as data length
# - dtype--type of the data
# - copy--copy data and by default it is False

# %%
import pandas as pd

# %%
#Method 1 : With list
list1 = [1,2,3,4,5] # List
ser1 = pd.Series(list1) # Series with list
print(ser1)
type(ser1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# pandas.core.series.Series

# %%
#Method 2 : Directly
ser2 = pd.Series(["a","b","c","d","e","f"])
print(ser2)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
#Method 3 : With Array
import numpy as np
arr1 = np.array([11,12,13,14,15])
print(arr1,"\n")
ser3 = pd.Series(arr1)
print(ser3)
# Out:
# [11 12 13 14 15]
#
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64

# %%
#Method 4 : With specific index
arr1 = np.array(["Amit","Arun","Pamkaj","Raman","Kartik"])
print(arr1,"\n")
ser4 = pd.Series(arr1,index = ["a","b","c","d","e"]) # Changing index according to our convenience
print(ser4)
# Out:
# ['Amit' 'Arun' 'Pamkaj' 'Raman' 'Kartik']
#
# a      Amit
# b      Arun
# c    Pamkaj
# d     Raman
# e    Kartik
# dtype: object

# %%
# Method 5 : With Dictionary
dic = {5:"x",6:"y",7:"z"} # Dictionary
ser5 = pd.Series(dic) # It Will take index and values as of dictionary
print(ser5)
# Out:
# 5    x
# 6    y
# 7    z
# dtype: object

# %%
ser6 = pd.Series(5,index = ("a","b","c","d"))
print(ser6)
# Out:
# a    5
# b    5
# c    5
# d    5
# dtype: int64

# %% [markdown]
# # Data Frames
# * 2-D Data Structure.
# * Mutable Size and Mutable Value
# * Heterogeneous data : As it stores different type of data in different coloums

# %% [markdown]
# pandas.DataFrame(data, index, columns, dtype, copy)
#
# Parameter description :
#
# - Data -- it takes various forms like list, ndarray, constant, dict, series.
# - index--its value is unique and same as data length
# - columns- For column labels, the optional default syntax is - np.arange(n). This is only true if no index is passed.
# - dtype--dtype of each column
# - copy--copy data and by default it is False

# %%
import pandas as pd

# %%
# Empty DataFrame
df = pd.DataFrame()
print(df)
type(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# pandas.core.frame.DataFrame

# %%
# DataFrames can be created directly with Dictionary
dic = {"Name" :["Ram", "Shyam", "Gita", "Pankaj", "Kal", "Rahul"],
      "Age":["24","36","54","81","17","22"],
      "Food":["Mango","Guava","Orange","Papita","Nimbu","Anaar"]} # Dictionary : With one key and multiple values

df = pd.DataFrame(dic)
print(df)
df # Key becomes the coloumn names and values become the data.
# Out:
#      Name Age    Food
# 0     Ram  24   Mango
# 1   Shyam  36   Guava
# 2    Gita  54  Orange
# 3  Pankaj  81  Papita
# 4     Kal  17   Nimbu
# 5   Rahul  22   Anaar
#      Name Age    Food
# 0     Ram  24   Mango
# 1   Shyam  36   Guava
# 2    Gita  54  Orange
# 3  Pankaj  81  Papita
# 4     Kal  17   Nimbu
# 5   Rahul  22   Anaar

# %%
dic = {"One":[1, 2, 5, 9, 8, 4, 58, 15],
      "Two":["D","R","E","I","O","P","Q","C"],
      "Three":[20.4,4.12,44.8,1.0,8.8,9.4,0.001,1]}

df = pd.DataFrame(dic)
df
# Out:
#    One Two   Three
# 0    1   D  20.400
# 1    2   R   4.120
# 2    5   E  44.800
# 3    9   I   1.000
# 4    8   O   8.800
# 5    4   P   9.400
# 6   58   Q   0.001
# 7   15   C   1.000

# %%
# Creating DataFrame using series
# First create dictionary using series.
dic = {"Sun": pd.Series([1,5,4,7,8,9,5,2],index = ["a","b","c","d","e","f","g","h"]),
      "Mon": pd.Series([1,5,6,8],index = ["b","h","d","g"])}
# It matches the indexs and form data
df = pd.DataFrame(dic) # Note how it adds NaN where there is no data, This happens only with series
df
# Out:
#    Sun  Mon
# a    1  NaN
# b    5  1.0
# c    4  NaN
# d    7  6.0
# e    8  NaN
# f    9  NaN
# g    5  8.0
# h    2  5.0

# %%
# If we specify the index it takes it as row index ie: Custom Index
dic = {'one' : pd.Series([1, 2, 3,6], index=['a', 'b', 'c', 'd']), 
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']),
   'Three' : pd.Series([2,5,7,8],index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(dic)
print(df)
# Out:
#    one  two  Three
# a    1    1      2
# b    2    2      5
# c    3    3      7
# d    6    4      8

# %%
pwd()# Gives present working directory
# Out:
# '/home/nobody11/Desktop/Py_my_prog_decodr'

# %%
# Reading data from file.
data = pd.read_csv("auto-mpg.csv") # Reading File
df_data = pd.DataFrame(data) # Converting data into DataFrame
df_data
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                 name  \
# 0    18.0    6  250.0   88    3139   14.5  71      US         ford mustang
# 1     9.0    8  304.0  193    4732   18.5  70      US             hi 1200d
# 2    36.1    4   91.0   60    1800   16.4  78    Asia     honda civic cvcc
# 3    18.5    6  250.0   98    3525   19.0  77      US         ford granada
# 4    34.3    4   97.0   78    2188   15.8  80  Europe            audi 4000
# ..    ...  ...    ...  ...     ...    ...  ..     ...                  ...
# 387  18.0    6  250.0   88    3021   16.5  73      US        ford maverick
# 388  27.0    4  151.0   90    2950   17.3  82      US     chevrolet camaro
# 389  29.5    4   98.0   68    2135   16.6  78    Asia      honda accord lx
# 390  17.5    6  250.0  110    3520   16.4  77      US   chevrolet concours
# 391  25.1    4  140.0   88    2720   15.4  78      US  ford fairmont (man)
#
#      color       size
# 0      red  27.370336
# ...

# %%
df_data.head() # This gives first 5 rows
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size
# 0  27.370336
# 1  62.199511
# 2   9.000000
# 3  34.515625
# 4  13.298178

# %%
df_data.hist() # Histogram of all the coloumn data
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cyl'}>,
#         <AxesSubplot:title={'center':'displ'}>],
#        [<AxesSubplot:title={'center':'hp'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'accel'}>],
#        [<AxesSubplot:title={'center':'yr'}>,
#         <AxesSubplot:title={'center':'size'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df_data.tail() # Print Bottom 5 Records
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr origin                 name  \
# 387  18.0    6  250.0   88    3021   16.5  73     US        ford maverick
# 388  27.0    4  151.0   90    2950   17.3  82     US     chevrolet camaro
# 389  29.5    4   98.0   68    2135   16.6  78   Asia      honda accord lx
# 390  17.5    6  250.0  110    3520   16.4  77     US   chevrolet concours
# 391  25.1    4  140.0   88    2720   15.4  78     US  ford fairmont (man)
#
#     color       size
# 387   red  25.351225
# 388  blue  24.173611
# 389  blue  12.661736
# 390   red  34.417778
# 391  blue  20.551111

# %%
df_data.shape # Gives number of coloumn and rows.
# Out:
# (392, 11)

# %%
# Extracting only one coloumn
mpg = df_data["mpg"] # it convers one coloumn in pd series
print(mpg)
type(mpg)
# Out:
# 0      18.0
# 1       9.0
# 2      36.1
# 3      18.5
# 4      34.3
#        ...
# 387    18.0
# 388    27.0
# 389    29.5
# 390    17.5
# 391    25.1
# Name: mpg, Length: 392, dtype: float64
# pandas.core.series.Series

# %%
mpg.head() # First five rows on mpg series
# Out:
# 0    18.0
# 1     9.0
# 2    36.1
# 3    18.5
# 4    34.3
# Name: mpg, dtype: float64

# %%
# Extracting two coloumns of the DataFrame
mpg_cyl = df_data["mpg","cyl"] # This gives error as it only takes one argument.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('mpg', 'cyl')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-6ef84eb73c5f> in <module>
# ...

# %%
mpg_cyl = df_data[["mpg","cyl"]] # We pass the two coloumns as single list.
print(type(mpg_cyl))
mpg_cyl # This takes required coloumn and creates a new DataFrame with these
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       mpg  cyl
# 0    18.0    6
# 1     9.0    8
# 2    36.1    4
# 3    18.5    6
# 4    34.3    4
# ..    ...  ...
# 387  18.0    6
# 388  27.0    4
# 389  29.5    4
# 390  17.5    6
# 391  25.1    4
#
# [392 rows x 2 columns]

# %%
#Extracting single coloumn as DataFrame
mpg = df_data[["mpg"]] # Double brackets convert it into DataFrame
print(type(mpg))
mpg
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       mpg
# 0    18.0
# 1     9.0
# 2    36.1
# 3    18.5
# 4    34.3
# ..    ...
# 387  18.0
# 388  27.0
# 389  29.5
# 390  17.5
# 391  25.1
#
# [392 rows x 1 columns]

# %%
data = pd.read_csv("auto-mpg.csv") # Reading File
df_data = pd.DataFrame(data) # Converting data into DataFrame
df_data

#Extracting coloumn names

col = df_data.columns
print(col)
type(col)
# Out:
# Index(['mpg', 'cyl', 'displ', 'hp', 'weight', 'accel', 'yr', 'origin', 'name',
#        'color', 'size'],
#       dtype='object')
# pandas.core.indexes.base.Index

# %%
data = pd.read_csv("auto-mpg.csv") # Reading File
df_data = pd.DataFrame(data) # Converting data into DataFrame
df_data

#Extracting all the data as nd-array

val = df_data.values
print(val)
type(val)
val.shape
# Out:
# [[18.0 6 250.0 ... 'ford mustang' 'red' 27.37033611]
#  [9.0 8 304.0 ... 'hi 1200d' 'green' 62.19951111]
#  [36.1 4 91.0 ... 'honda civic cvcc' 'blue' 9.0]
#  ...
#  [29.5 4 98.0 ... 'honda accord lx' 'blue' 12.66173611]
#  [17.5 6 250.0 ... 'chevrolet concours' 'red' 34.41777778]
#  [25.1 4 140.0 ... 'ford fairmont (man)' 'blue' 20.55111111]]
# (392, 11)

# %% [markdown]
# # Panel Data Type/Structure
#
# Panel is a three dimensional pandas data structure .
# * It is can store heterogeneous data.
# * Size and data is mutable in panel.
# * It is hard to explain it graphically but we can compare it by 3D cube.
# * It is like a container of dataframes.
# * RGB Images

# %% [markdown]
# # Reading File in Pandas

# %% [markdown]
# To import csv , Excel, json file follow below steps:
# * Import pandas as pd
# * Variable_name=pd.read_csv(“File path”) #for csv
# * Variable_name=pd.read_excel(“File path”) #for excel file, Excel file has lots of formatting. Colour, Border, Bold. Lots of parameters required. Thus used less.
# * Variable_name=pd.read_json(“File path”) #for json file , Same as excel
#
# --------- After doing above step----------------------
# Convert it into dataframe :
#
# df=pd.DataFrame(“Variable_name”)

# %%
#Importing Excel File
data_e = pd.read_excel("excel_test.xlsx")
df_e = pd.DataFrame(data_e)
df_e
# Out:
#    ID Sex
# 0   1   M
# 1   2   F
# 2   3   M
# 3   4   F
# 4   5   F

# %%
#Importing CSV files
data_c = pd.read_csv("auto-mpg.csv")
df_c = pd.DataFrame(data_c)
df_c.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size
# 0  27.370336
# 1  62.199511
# 2   9.000000
# 3  34.515625
# 4  13.298178

# %% [markdown]
# # Filtering of Data wrt Row and Coloumn

# %% [markdown]
# ### Indexing and Selecting Data with Pandas

# %% [markdown]
# * Indexing in Pandas : Indexing means selecting the columns and rows of data from the dataframe.
# * Selecting in Pandas: Selecting means selecting all the rows and some of the columns or some of the rows and all of the columns, or some of the rows and columns.
#
# Pandas has some inbuilt function for Indexing :
#
# ● Dataframe.[ ] ; This function also known as indexing operator
#
# ● Dataframe.loc[ ]: location, This function is used for labels.
#
# ● Dataframe.iloc[ ]: integer location, This function is used for positions or integer based
#
# ● Dataframe.ix[ ]: This function is used for both label and integer based

# %%
import pandas as pd
data = pd.read_csv("auto-mpg.csv")
df = pd.DataFrame(data)
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                 name  \
# 0    18.0    6  250.0   88    3139   14.5  71      US         ford mustang
# 1     9.0    8  304.0  193    4732   18.5  70      US             hi 1200d
# 2    36.1    4   91.0   60    1800   16.4  78    Asia     honda civic cvcc
# 3    18.5    6  250.0   98    3525   19.0  77      US         ford granada
# 4    34.3    4   97.0   78    2188   15.8  80  Europe            audi 4000
# ..    ...  ...    ...  ...     ...    ...  ..     ...                  ...
# 387  18.0    6  250.0   88    3021   16.5  73      US        ford maverick
# 388  27.0    4  151.0   90    2950   17.3  82      US     chevrolet camaro
# 389  29.5    4   98.0   68    2135   16.6  78    Asia      honda accord lx
# 390  17.5    6  250.0  110    3520   16.4  77      US   chevrolet concours
# 391  25.1    4  140.0   88    2720   15.4  78      US  ford fairmont (man)
#
#      color       size
# 0      red  27.370336
# ...

# %%
print(df['weight'],"\n") # Single Coloumn
print(df[["mpg","weight"]]) # Two or more coloumns
# Out:
# 0      3139
# 1      4732
# 2      1800
# 3      3525
# 4      2188
#        ...
# 387    3021
# 388    2950
# 389    2135
# 390    3520
# 391    2720
# Name: weight, Length: 392, dtype: int64
#
#       mpg  weight
# 0    18.0    3139
# 1     9.0    4732
# 2    36.1    1800
# 3    18.5    3525
# 4    34.3    2188
# ..    ...     ...
# 387  18.0    3021
# 388  27.0    2950
# 389  29.5    2135
# 390  17.5    3520
# 391  25.1    2720
#
# [392 rows x 2 columns]

# %% [markdown]
# ### Using loc
#
# * It helps in selecting the rows and coloumn

# %%
print(df.loc[0],"\n") # Full First Row
print(df.loc[1]) # Full second Row
# Out:
# mpg               18.0
# cyl                  6
# displ            250.0
# hp                  88
# weight            3139
# accel             14.5
# yr                  71
# origin              US
# name      ford mustang
# color              red
# size         27.370336
# Name: 0, dtype: object
#
# mpg             9.0
# cyl               8
# displ         304.0
# hp              193
# weight         4732
# accel          18.5
# yr               70
# origin           US
# name       hi 1200d
# color         green
# size      62.199511
# Name: 1, dtype: object

# %%
df.loc[:,"weight"] # Single Coloumn
# Out:
# 0      3139
# 1      4732
# 2      1800
# 3      3525
# 4      2188
#        ...
# 387    3021
# 388    2950
# 389    2135
# 390    3520
# 391    2720
# Name: weight, Length: 392, dtype: int64

# %%
df.loc[:,:] # Everything
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                 name  \
# 0    18.0    6  250.0   88    3139   14.5  71      US         ford mustang
# 1     9.0    8  304.0  193    4732   18.5  70      US             hi 1200d
# 2    36.1    4   91.0   60    1800   16.4  78    Asia     honda civic cvcc
# 3    18.5    6  250.0   98    3525   19.0  77      US         ford granada
# 4    34.3    4   97.0   78    2188   15.8  80  Europe            audi 4000
# ..    ...  ...    ...  ...     ...    ...  ..     ...                  ...
# 387  18.0    6  250.0   88    3021   16.5  73      US        ford maverick
# 388  27.0    4  151.0   90    2950   17.3  82      US     chevrolet camaro
# 389  29.5    4   98.0   68    2135   16.6  78    Asia      honda accord lx
# 390  17.5    6  250.0  110    3520   16.4  77      US   chevrolet concours
# 391  25.1    4  140.0   88    2720   15.4  78      US  ford fairmont (man)
#
#      color       size
# 0      red  27.370336
# ...

# %%
df.loc[0:7,"weight"] # First Seven Rows of single coloumn
# Out:
# 0    3139
# 1    4732
# 2    1800
# 3    3525
# 4    2188
# 5    2615
# 6    2265
# 7    2511
# Name: weight, dtype: int64

# %%
df.loc[0:8,"weight":"color"] # First 9 Coloumn, from weight to color coloumn
# Out:
#    weight  accel  yr  origin                     name  color
# 0    3139   14.5  71      US             ford mustang    red
# 1    4732   18.5  70      US                 hi 1200d  green
# 2    1800   16.4  78    Asia         honda civic cvcc   blue
# 3    3525   19.0  77      US             ford granada    red
# 4    2188   15.8  80  Europe                audi 4000   blue
# 5    2615   14.8  81    Asia             datsun 200sx   blue
# 6    2265   15.2  80    Asia           toyota corolla   blue
# 7    2511   18.0  72  Europe      volkswagen 411 (sw)   blue
# 8    4295   14.9  77      US  mercury cougar brougham  green

# %%
df.loc[::2,"weight":"color":2] # Skipping the rows and coloumn
# Out:
#      weight  yr                     name
# 0      3139  71             ford mustang
# 2      1800  78         honda civic cvcc
# 4      2188  80                audi 4000
# 6      2265  80           toyota corolla
# 8      4295  77  mercury cougar brougham
# ..      ...  ..                      ...
# 382    3425  77            buick skylark
# 384    2160  82         nissan stanza xe
# 386    1975  81           datsun 210 mpg
# 388    2950  82         chevrolet camaro
# 390    3520  77       chevrolet concours
#
# [196 rows x 3 columns]

# %%
df.loc[::2,["weight","size","color"]] # Selecting Rows and coloumns manually
# Out:
#      weight       size  color
# 0      3139  27.370336    red
# 2      1800   9.000000   blue
# 4      2188  13.298178   blue
# 6      2265  14.250625   blue
# 8      4295  51.241736  green
# ..      ...        ...    ...
# 382    3425  32.585069    red
# 384    2160  12.960000   blue
# 386    1975  10.835069   blue
# 388    2950  24.173611   blue
# 390    3520  34.417778    red
#
# [196 rows x 3 columns]

# %% [markdown]
# ### iloc (integer location)
#
# df.loc : takes coloumn/lable name
#
# df.iloc : takes coloumn index

# %%
#df.loc[:,2] this also work but display of data is not good this way
df.iloc[:,[2]] #Second Coloumn via Index
# Out:
#      displ
# 0    250.0
# 1    304.0
# 2     91.0
# 3    250.0
# 4     97.0
# ..     ...
# 387  250.0
# 388  151.0
# 389   98.0
# 390  250.0
# 391  140.0
#
# [392 rows x 1 columns]

# %%
df.iloc[:,0:2] # First 2 coloumns
# Out:
#       mpg  cyl
# 0    18.0    6
# 1     9.0    8
# 2    36.1    4
# 3    18.5    6
# 4    34.3    4
# ..    ...  ...
# 387  18.0    6
# 388  27.0    4
# 389  29.5    4
# 390  17.5    6
# 391  25.1    4
#
# [392 rows x 2 columns]

# %%
df.iloc[0:5,0:2] # Subset of whole data
# Out:
#     mpg  cyl
# 0  18.0    6
# 1   9.0    8
# 2  36.1    4
# 3  18.5    6
# 4  34.3    4

# %%
df.iloc[0:10,[1,8,4,2]] # Particular coloumns
# Out:
#    cyl                     name  weight  displ
# 0    6             ford mustang    3139  250.0
# 1    8                 hi 1200d    4732  304.0
# 2    4         honda civic cvcc    1800   91.0
# 3    6             ford granada    3525  250.0
# 4    4                audi 4000    2188   97.0
# 5    4             datsun 200sx    2615  119.0
# 6    4           toyota corolla    2265  108.0
# 7    4      volkswagen 411 (sw)    2511  121.0
# 8    8  mercury cougar brougham    4295  302.0
# 9    8              ford torino    3449  302.0

# %% [markdown]
# ### Missing Data Handling

# %%
import pandas as pd
data_t = pd.read_csv("titanic_train.csv")
df_t = pd.DataFrame(data_t)
df_t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_t.isnull() # Gives True or False. If there is no value then True. If some value then false
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df_t.isnull().any() # This gives coloumns that have any missing values. Here age, cabin and fare have missing values
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df_t.isnull().sum() # This gives number of missing values for that coloumn
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_t.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Remove rows with missing data

# %%
df_row = df_t.isnull().any(axis=1) # Rows with null in them
df_row
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
#Extracting index values of rows with null in them
df_row_index_with_null = df_t.index[df_row]
df_row_index_with_null # All these rows have null in them 708 Rows
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=708)

# %%
#Doing above steps in single line
df_row_index_with_null = df_t.index[df_t.isnull().any(axis=1)]
df_row_index_with_null
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=708)

# %%
df_row_index_with_null_in_embarked_coloumn = df_t.index[df_t[["Embarked"]].isnull().any(axis=1)]
df_row_index_with_null_in_embarked_coloumn # Two rows 61 and 829 with null value in Embarked coloumn
# Out:
# Int64Index([61, 829], dtype='int64')

# %%
# Deleting an coloumn inplace = true # Permanent change in main data
df_t.drop("Cabin",axis = 1,inplace = True)# Delete Cabin Coloumn, which is axis=1(Coloumn),inplace=ture makes changes permanent

# %%
df_t # Cabin is not here in original data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Deleting an coloumn inplace = false
df_t.drop("Age",axis = 1,inplace = False) # Deleted temporarily
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df_t # Here Age is as it is
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Deleting Rows witn null values in them
df_t.drop(df_row_index_with_null,axis = 0,inplace=False) # Only 183 Rows remain
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_t.drop(df_row_index_with_null_in_embarked_coloumn,axis = 0,inplace=False) # Deleted all the rows where embarked is null
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Handling Duplicate Data(Rows)

# %%
import pandas as pd

students = [('jack', 34, 'Sydeny'),
            ('Riti', 30, 'Delhi'),
            ('Aadi', 16, 'New York'),
            ('Riti', 30, 'Delhi'),
            ('Riti', 30, 'Delhi'),
            ('Riti', 30, 'Mumbai'),
            ('Aadi', 40, 'London'),
            ('Sachin', 30, 'Delhi')
            ]
df=pd.DataFrame(students)#Creating DataFrame from List of tuples. When coloumn name/lable not given it assigns index 
df
# Out:
#         0   1         2
# 0    jack  34    Sydeny
# 1    Riti  30     Delhi
# 2    Aadi  16  New York
# 3    Riti  30     Delhi
# 4    Riti  30     Delhi
# 5    Riti  30    Mumbai
# 6    Aadi  40    London
# 7  Sachin  30     Delhi

# %%
df.duplicated() # Gives Duplicate items in form of boolean
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
duplicate = df[df.duplicated()] # Shows all rows with same data
duplicate
# Out:
#       0   1      2
# 3  Riti  30  Delhi
# 4  Riti  30  Delhi

# %%
df.drop_duplicates(keep = "first",inplace = True) # To delete the duplicate items. And keeping the first one
df
# Out:
#         0   1         2
# 0    jack  34    Sydeny
# 1    Riti  30     Delhi
# 2    Aadi  16  New York
# 5    Riti  30    Mumbai
# 6    Aadi  40    London
# 7  Sachin  30     Delhi

# %% [markdown]
# ## Adding and Deleting Coloumns

# %%
import pandas as pd

#Method 1 : Adding Coloumn using List.

df = {'Name': ['Krish', 'Pankaj', 'Gaurav', 'Anju'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'To_Course': ['B.tech', 'CA', 'Bsc', 'MBBS']}

df = pd.DataFrame(df)
df
# Out:
#      Name  Height To_Course
# 0   Krish     5.1    B.tech
# 1  Pankaj     6.2        CA
# 2  Gaurav     5.1       Bsc
# 3    Anju     5.2      MBBS

# %%
State = ['Delhi', 'Bangalore', 'Chennai', 'Patna'] # Coloumn as list to be added

df["State"] = State # Declaring new coloumn name and passing list into it.

# %%
df
# Out:
#      Name  Height To_Course      State
# 0   Krish     5.1    B.tech      Delhi
# 1  Pankaj     6.2        CA  Bangalore
# 2  Gaurav     5.1       Bsc    Chennai
# 3    Anju     5.2      MBBS      Patna

# %%
# Method 2 of adding new coloumn. Using insert method

df.insert(1,"Income",[30000,45000,27000,13000]) # coloumn_index, name, data

# %%
df
# Out:
#      Name  Income  Height To_Course      State
# 0   Krish   30000     5.1    B.tech      Delhi
# 1  Pankaj   45000     6.2        CA  Bangalore
# 2  Gaurav   27000     5.1       Bsc    Chennai
# 3    Anju   13000     5.2      MBBS      Patna

# %%
# Method 3: New coloumn = math operation on old coloumn : Most Used

df["New_computed_coloumn"] = df["Income"]*df["Height"]
df
# Out:
#      Name  Income  Height To_Course      State  New_computed_coloumn
# 0   Krish   30000     5.1    B.tech      Delhi              153000.0
# 1  Pankaj   45000     6.2        CA  Bangalore              279000.0
# 2  Gaurav   27000     5.1       Bsc    Chennai              137700.0
# 3    Anju   13000     5.2      MBBS      Patna               67600.0

# %%
#Method 4 : Using Dictionary
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
df = pd.DataFrame(data)
df
# Out:
#      Name  Height Qualification
# 0     Jai     5.1           Msc
# 1  Princi     6.2            MA
# 2  Gaurav     5.1           Msc
# 3    Anuj     5.2           Msc

# %%
col_add = {'Delhi': 'Jai', 'Bangalore': 'Princi',
           'Patna': 'Gaurav', 'Chennai': 'Anuj'} # Coloumn as dictionary

df["Address"] = col_add

# %%
df
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           Msc      Delhi
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           Msc      Patna
# 3    Anuj     5.2           Msc    Chennai

# %% [markdown]
# # Merging DataFrames

# %% [markdown]
# Pandas inbuilt function for merging :
#
# * pd.concat(df1,df2)
#
# * dataframe.append(df1)
#
# * pd.merge()

# %% [markdown]
# ### concat

# %% [markdown]
# pandas.concat() function merge two or more Dataframe both row and column wise.

# %%
import pandas as pd
#Different index,  verticle concat
df1=pd.DataFrame(
    {
      'A':[1,2],
     'B':[3,4],
    },
    index=[0,1],
    )

df2=pd.DataFrame(
    {
      'A':[5,6],
     'B':[7,8],
    },
    index=[2,3],
    )

df3=pd.DataFrame(
    {
      'C':[1,5],
     'D':[4,9],
    },
    index=[4,5],
    )

df=pd.concat([df1,df2,df3]) # Using concat with two parameters

print(df1)
print("--------")
print(df2)
print("--------")
print(df)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# --------
#    A  B
# 2  5  7
# 3  6  8
# --------
#      A    B    C    D
# 0  1.0  3.0  NaN  NaN
# 1  2.0  4.0  NaN  NaN
# 2  5.0  7.0  NaN  NaN
# 3  6.0  8.0  NaN  NaN
# 4  NaN  NaN  1.0  4.0
# 5  NaN  NaN  5.0  9.0

# %%
# Method 2:
#Concat with same index
df1=pd.DataFrame(
    {
      'A':[1,2],
     'B':[3,4],
    },
    )
df2=pd.DataFrame(
    {
      'A':[5,6],
     'B':[7,8],
    },
    )

df=pd.concat([df1,df2]) #This forms repeated index
print(df1)
print("--------")
print(df2)
print("--------")
print(df)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# --------
#    A  B
# 0  5  7
# 1  6  8
# --------
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
# To Avoide repeaded index in above
df=pd.concat([df1,df2], ignore_index = True) #This gives new index to added rows
df
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  6  8

# %%
# using Concat to add Horizontly
df1=pd.DataFrame(
    {
      'A':[1,2],
     'B':[3,4],
    },
    )
df2=pd.DataFrame(
    {
      'C':[5,6],
     'D':[7,8],
    },
    )

df=pd.concat([df1,df2],axis = 1) #THere Axis = 1 means to add Horizontly. Coloumn wise
print(df1)
print("--------")
print(df2)
print("--------")
print(df)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# --------
#    C  D
# 0  5  7
# 1  6  8
# --------
#    A  B  C  D
# 0  1  3  5  7
# 1  2  4  6  8

# %% [markdown]
# ### Append

# %% [markdown]
# It adds only rowwise. That is Vertically

# %%
df1=pd.DataFrame(
    {
      'A':[1,2],
     'B':[3,4],
    },
    )
df2=pd.DataFrame(
    {
      'A':[5,6],
     'B':[7,8],
    },
    )
print(df1)
print()
print(df2)
# Out:
#    A  B
# 0  1  3
# 1  2  4
#
#    A  B
# 0  5  7
# 1  6  8

# %%
df1.append(df2) # Adding Verticaly
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
df1=pd.DataFrame(
    {
      'A':[1,2],
     'B':[3,4],
    },
    )
df2=pd.DataFrame(
    {
      'C':[5,6],
     'D':[7,8],
    },
    )
print(df1)
print()
print(df2)
# Out:
#    A  B
# 0  1  3
# 1  2  4
#
#    C  D
# 0  5  7
# 1  6  8

# %%
df1.append(df2) #Adds vertically only
# Out:
#      A    B    C    D
# 0  1.0  3.0  NaN  NaN
# 1  2.0  4.0  NaN  NaN
# 0  NaN  NaN  5.0  7.0
# 1  NaN  NaN  6.0  8.0
